# %%
import pandas as pd

# %%
column_names = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 
    'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 
    'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 
    'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 
    'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 
    'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 
    'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 
    'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 
    'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 
    'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'target', 'difficulty_level'
]

# %%
df_completo=pd.read_csv('KDDTrain+.txt', names=column_names)

# %%
columnas_elegidas= [
    'protocol_type', 'service', 'duration', 'src_bytes', 
    'dst_bytes', 'logged_in', 'count', 'target'
]

# %%
df_reducido = df_completo[columnas_elegidas].sample(n=10000, random_state=42)

# %%
df_reducido['target'] = df_reducido['target'].apply(lambda x: 'normal' if x == 'normal' else 'ataque')

# %%
df_reducido.to_csv('dataset_reducido.csv', index=False)

# %%
print(f"El nuevo dataset tiene {df_reducido.shape[0]} filas y {df_reducido.shape[1]} columnas.")
display(df_reducido.head())
# Out:
# El nuevo dataset tiene 10000 filas y 8 columnas.
#       protocol_type   service  duration  src_bytes  dst_bytes  logged_in  \
# 378             udp  domain_u         0         36          0          0
# 32038           tcp      http         0          0          0          0
# 86399           tcp     pop_3         0          0          0          0
# 74412           tcp   private         0          0          0          0
# 52951           tcp   private         0          0          0          0
#
#        count  target
# 378        2  normal
# 32038     42  ataque
# 86399    284  ataque
# 74412    110  ataque
# 52951      1  ataque
